# %%
import numpy as np
import math
import random
import pprint
import pygame as pg

# %%
#===========CHANGABLE PARAMETERS=================
REWARD     = 1
PENALTY    = -1
DISCOUNT   = 0.9
LEARN_RATE = 0.1
def get_explore_rate(epoch):
    return max(0.1,1-math.log(epoch)/10)

#===========DEFINE CONSTANTS AND DICS=============
WALL_LEN = 1
PADDLE_H = 0.2

init_state = (0.5, 0.5, 0.03, 0.01, 0.5 - PADDLE_H / 2)

ACTION_DIC={0:-0.04, #'UP'
            1:0,     #'STAY'
            2:0.04}  #'DOWN'

BOARD_SIZE = 12
X_VBALL_DIS = [-1,1]
Y_VBALL_DIS = [-1,0,1]

PADDLE_SPACE = 12
PADDLE_X     = 1

STATE_SPACE = (BOARD_SIZE,BOARD_SIZE,len(X_VBALL_DIS),len(Y_VBALL_DIS),PADDLE_SPACE)

X_V_TSH = 0.03
Y_V_TSH = 0.015

# %%
#==============DEFINE STATE CLASS===============
class state:
    
    def __init__(self,ball_x,ball_y,velocity_x,velocity_y,paddle_y,reward,end_state = 0):
        self.ball_x = ball_x              #real numbers on the interval [0,1]
        self.ball_y = ball_y
        self.velocity_x = velocity_x
        self.velocity_y = velocity_y
        self.paddle_y = paddle_y
        self.reward = reward
        self.state_tuple = (ball_x,ball_y,velocity_x,velocity_y,paddle_y)
        self.end_state = end_state
        self._extract()
        
    def _extract(self):
        self.x_grid = math.floor(11*self.ball_x)
        self.y_grid = math.floor(11*self.ball_y)
        if(self.velocity_x>0): 
            self.x_v_sign = 1
        else: 
            self.x_v_sign = -1
            
        if(self.velocity_y>0):
            self.y_v_sign = 1
        else: 
            self.y_v_sign = -1
        
        self.paddle_grid = math.floor(11 * self.paddle_y / (1 - PADDLE_H))
        self.space_tuple = (self.x_grid,self.y_grid,self.x_v_sign,self.y_v_sign,self.paddle_grid)

# %%
math.floor(11 * 0.8 / (1 - PADDLE_H))
# Out:
# 11

# %%
#=======DEFINE MORE HELPER FUNCTIONS===========
def bounce(cur_state,action):
#     print('ENTER!!!!')
    n_ball_v_x = cur_state.velocity_x
    n_ball_v_y = cur_state.velocity_y
    
    n_ball_x = cur_state.ball_x + n_ball_v_x
    n_ball_y = cur_state.ball_y + n_ball_v_y

    #======paddle should in range(0,0.8)
    n_paddle_y = min(WALL_LEN-PADDLE_H,max(0,cur_state.paddle_y + action))
    
    c_reward = 0
    
    #==the ball is off the top of the screen==
    if n_ball_y < 0:
#         print('1111111111111111111111111')
        n_ball_y = -n_ball_y
        n_ball_v_y = -n_ball_v_y
        
    #==the ball is off the bottom of the screen==
    if n_ball_y > 1:
#         print('22222222222222222222222222')
        n_ball_y = 2*WALL_LEN-n_ball_y
        n_ball_v_y = -n_ball_v_y
        
    #==the ball is off the left edge of the screen==
    if n_ball_x < 0:
#         print('33333333333333333333333333')
        n_ball_x = -n_ball_x
        n_ball_v_x = -n_ball_v_x
        
    #== the ball bouncing off the paddle==
#     print('n_paddle_y+PADDLE_H',n_paddle_y+PADDLE_H,'n_ball_y', n_ball_y,'n_paddle_y', n_paddle_y)
#     print(n_paddle_y+PADDLE_H <= n_ball_y <= n_paddle_y)
#     print(n_ball_x >= 1)
    if n_ball_x >= 1 and (n_paddle_y+PADDLE_H >= n_ball_y >= n_paddle_y):
#         print('yuayyyaysaysdyuasfhiuadsfhiua!')
        n_ball_x = 2*PADDLE_X - n_ball_x
        n_ball_v_x, n_ball_v_y = update_speed_rand(n_ball_v_x,n_ball_v_y)
        c_reward = REWARD
    elif n_ball_x > 1:
#         print('444444444444444444444444444')
        c_reward = PENALTY
    return n_ball_x,n_ball_y,n_ball_v_x,n_ball_v_y,n_paddle_y,c_reward

def update_speed_rand(velocity_x,velocity_y):
    vx_delta = random.choice(range(-15,16,1))/1000
    vy_delta = random.choice(range(-3,4,1))  /100
    sign_x = velocity_x/abs(velocity_x)
    sign_y = velocity_y/abs(velocity_y)
    n_ball_v_x = sign_x*max(X_V_TSH,abs(vx_delta+velocity_x))
    n_ball_v_y = sign_y*max(Y_V_TSH,abs(vy_delta+velocity_y))
    return n_ball_v_x, n_ball_v_y

def check_termination(cur_state):
    pad_rang = range(cur_state.paddle_y-PADDLE_H,cur_state.paddle_y)
    if cur_state.ball_x>=WALL_LEN and cur_state.ball_y not in pad_rang:
        return True
    else:
        return False
    
def get_act(cur_state,i,q):
    if random.random()<get_explore_rate(i):
        return random.choice(range(0,3,1))
    return np.argmax(q.get_table(cur_state.space_tuple))
    
        
def proceed_one_step(cur_state,action):

    n_ball_x,n_ball_y,n_ball_v_x,n_ball_v_y,n_paddle_y,c_reward = bounce(cur_state,action)
    end = 0
    if c_reward == -1:
        end = 1
#     print(n_ball_x,n_ball_y,n_ball_v_x,n_ball_v_y,n_paddle_y,c_reward,end,action)
    n_state = state(n_ball_x,n_ball_y,n_ball_v_x,n_ball_v_y,n_paddle_y,c_reward,end_state=end)
    return n_state

# %%
#=============DEFINE Q-AGENT CLASS==============
class q_agent:
    
    def __init__(self):
        self.q_table = np.zeros(STATE_SPACE+(len(ACTION_DIC),)) 
        self.end_state = 0
        
    def set_table(self,loc,val):
        self.q_table[loc] = val
    
    def get_table(self,loc):
#         print(loc)
        return self.q_table[loc]
    
    def get_act(self,cur_state,i):
        if random.random()<get_explore_rate(i):
            return random.choice(range(0,3,1))
        return np.argmax(self.get_table(cur_state.space_tuple))

# %%
#=============DEFINE TRAIN FUCNTION=============
#init_state = (0.5, 0.5, 0.03, 0.01, 0.5 - PADDLE_H / 2)
#self.space_tuple = (self.x_grid,self.y_grid,self.x_v_sign,self.y_v_sign,self.paddle_grid)



def train(epoch_num,q_ag):

    tot_bounce = 0
    for i in range(1,epoch_num+1):
#         print('i=',i)
        temp_bounce = 0
        cur_state = state(0.5, 0.5, 0.03, 0.01, 0.5 - PADDLE_H / 2,0)
        while True:
            action = q_ag.get_act(cur_state,i)
#             action = 1
#             print('act=',action)
            n_state = proceed_one_step(cur_state,ACTION_DIC[action])
            old_val = q_ag.get_table(cur_state.space_tuple+(action,))


            prd_max = np.max(q_ag.get_table(n_state.space_tuple))
            prd_tuple = (n_state.x_grid,n_state.y_grid,n_state.x_v_sign,n_state.y_v_sign,n_state.paddle_grid,prd_max)

            new_val = (1-LEARN_RATE)*old_val + LEARN_RATE*(n_state.reward + DISCOUNT*prd_max)
            q_ag.set_table(cur_state.space_tuple+(action,),new_val)
#             print('22222222222=',prd_max)
#             print('33333333333333=',n_state.space_tuple+(action,))
#             print('44444444444=',q_ag.get_table(n_state.space_tuple+(action,)))
            if n_state.end_state == 1:
                break
            if n_state.reward == REWARD:
                temp_bounce+=1
#                 print('this round=',temp_bounce)
            cur_state = n_state
        tot_bounce+=temp_bounce
#         print()
#         print()
        if i%1000 == 0:
            print('loop',i)
            print(q_ag.q_table.sum())
            print('now average bounce is', tot_bounce/i)
            print('bounce=',tot_bounce)

# %% [markdown]
# print(n_ball_x,n_ball_y,n_ball_v_x,n_ball_v_y,n_paddle_y,c_reward,end)

# %%
q_ag = q_agent()
train(100000,q_ag)
# Out:
# this round= 1
# this round= 2
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 22
# this round= 23
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 22
# this round= 23
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 22
# this round= 23
# this round= 24
# this round= 25
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 22
# this round= 23
# this round= 24
# this round= 25
# this round= 26
# this round= 27
# this round= 28
# this round= 29
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 22
# this round= 23
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 22
# this round= 23
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 22
# this round= 23
# this round= 24
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 22
# this round= 23
# this round= 24
# this round= 25
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 22
# this round= 23
# this round= 24
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 22
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# ...
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 22
# this round= 23
# this round= 24
# this round= 25
# this round= 26
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 22
# this round= 23
# this round= 24
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 22
# this round= 23
# this round= 24
# this round= 25
# this round= 26
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 22
# this round= 23
# this round= 24
# this round= 25
# this round= 26
# this round= 27
# this round= 28
# this round= 29
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 1
# this round= 2
# this round= 3
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 22
# this round= 23
# this round= 24
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 1
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 22
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# this round= 11
# this round= 12
# this round= 13
# this round= 14
# this round= 15
# this round= 16
# this round= 17
# this round= 18
# this round= 19
# this round= 20
# this round= 21
# this round= 22
# this round= 23
# this round= 24
# this round= 25
# this round= 1
# this round= 2
# this round= 3
# this round= 4
# this round= 5
# this round= 6
# this round= 7
# this round= 8
# this round= 9
# this round= 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-5f0cc1a77d07> in <module>()
#       1 q_ag = q_agent()
# ----> 2 train(100000,q_ag)
#
# <ipython-input-55-392bfb394f4d> in train(epoch_num, q_ag)
#      32             if n_state.reward == REWARD:
#      33                 temp_bounce+=1
# ---> 34                 print('this round=',temp_bounce)
#      35             cur_state = n_state
#      36         tot_bounce+=temp_bounce
#
# ~/anaconda3/lib/python3.6/site-packages/ipykernel/iostream.py in write(self, string)
#     358                     self.flush()
#     359             else:
# --> 360                 self._schedule_flush()
#     361
#     362     def writelines(self, sequence):
#
# ~/anaconda3/lib/python3.6/site-packages/ipykernel/iostream.py in _schedule_flush(self)
#     295         return self.pub_thread is None
#     296
# --> 297     def _schedule_flush(self):
#     298         """schedule a flush in the IO thread
#     299
#
# KeyboardInterrupt:

# %%
f = open("see.txt",'w')
f.write(np.array2string(q_ag.q_table, precision=2, separator=',',suppress_small=True))
f.close()
pprint.pprint(q_ag.q_table)

# %%
class A:
    def __init__(self,val):
        self.val = val
        
    def set_val(self,val):
        self.val = val
        
    def get_Val(self):
        return self.val

# %%
def test(clas):
    clas.set_val(clas.get_Val()+100)
    
def test1(clas):
    clas.set_val(11)
    test(clas)

# %%
th = A(999)

# %%
th.get_Val()

# %%
n = 1
if(not(n+1)):
    print('kk')

# %%
np.shape(np.zeros(STATE_SPACE+(3,)))

# %%
l = np.zeros(STATE_SPACE+(3,))
l[1][1][1][1][1][1] = 1
t = (1,1,1,1,1)
act = 10
l[t+(act,)] = 1000
print(l[1][1][1][1][1][1])

# %%
test = np.array([[1,2,3],[4,5,6]])

# %%
state(0.5, 0.5, 0.03, 0.01, 0.5 - PADDLE_H / 2,0)

# %%
def change(cur_st):
    cur_st.

# %%
cur_state = state(0.5, 0.5, 0.03, 0.01, 0.5 - PADDLE_H / 2,0)

# %%
random.choice(range(0,3,1))

# %%
0.4+0.2  0.5 <= 0.4
# Out:
# False

# %%
0.4+0.2 <= 0.5
# Out:
# False
